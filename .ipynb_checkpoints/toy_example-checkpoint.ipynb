# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from configuration import conf
from utils.data_loader import load_mnist
from models.base import Linear_base_model, Convolutional_base_model
from utils.visualise import *
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import pandas as pd
from playground.env import Environment

# %%
env = Environment()
x,y = env.load_data()

# %%
x.shape
# Out:
# (9000, 2)

# %%
df = pd.DataFrame(data={'x':x[:,0],'y':x[:,1],'label':y})

# %%
conf.num_distr = '5'
sns.scatterplot(x='x',y='y',hue='label',data=df)

# %%
trainloader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(torch.from_numpy(x).type(torch.FloatTensor),
                                           torch.from_numpy(y.reshape(y.shape[0],1)).type(torch.int64)),
                                          batch_size=10, shuffle=True, num_workers=0)

# %%
def plot_means():
    means = []
    stds = []
    with torch.no_grad():
        for cls in range(2):
            for i in model.last_layer.centers[cls]:
                means.append(i[0].detach().numpy())
                stds.append(i[1].detach().numpy())
    means = np.array(means)
    print('mean')
    print(means)
    print('stds')
    print(np.log(1+np.exp(stds)))
    mean_len = len(means)
    plt.scatter(means[range(mean_len//2),0],means[range(mean_len//2),1], label='class 0')
    plt.scatter(means[range(mean_len//2, mean_len),0],means[range(mean_len//2,mean_len),1], label='class 1')
    plt.legend()

# %% [markdown]
# # Dynamic Estimator

# %%
conf.last_layer = 'DY'
model = Linear_base_model()
model.train_model(trainloader, verbose=0)

# %%
plt.plot(model.history['loss'])

# %%
plot_means()
# Out:
# mean
# [[ 1.5101697e+00  1.5158561e+00]
#  [-1.4979049e+00 -1.4922860e+00]
#  [-1.5123117e+00  1.5037248e+00]
#  [-6.6510485e-03  7.1323691e-03]
#  [ 1.4985127e+00 -1.4995203e+00]
#  [-1.4295231e-03 -1.5028262e+00]
#  [ 3.6299573e-03  1.5191549e+00]
#  [ 1.4963299e+00  8.4993586e-02]
#  [ 1.5090243e+00 -7.4290283e-02]
#  [-1.5153880e+00 -9.7308615e-03]]
# stds
# [[0.6745966  0.67182547]
#  [0.66797036 0.67891544]
#  [0.67821395 0.6773238 ]
#  [0.60744435 0.6056536 ]
#  [0.67676723 0.6698373 ]
#  [0.5887134  0.67147684]
#  [0.59808004 0.6652031 ]
#  [0.54248947 0.4471057 ]
#  [0.5679109  0.46359405]
#  [0.6650741  0.5915956 ]]

# %% [markdown]
# # Density Estimator

# %%
conf.last_layer = 'DE'
model = Linear_base_model()
model.train_model(trainloader, verbose=0)

# %%
plot_means()
# Out:
# mean
# [[-1.4973712e+00  1.5050631e+00]
#  [ 1.9219965e+00 -1.4913950e+00]
#  [-3.2880155e-03  3.6876106e-03]
#  [-2.2927616e+00 -1.4979352e+00]
#  [ 1.5130688e+00  1.5082576e+00]
#  [-1.5040287e+00 -7.4095977e-03]
#  [ 1.5039598e+00 -9.5933359e-03]
#  [ 6.2074065e-03 -1.5150583e+00]
#  [ 4.3836704e-01  1.4608570e+00]
#  [-7.9563710e-05  1.5119785e+00]]
# stds
# [[0.6728741  0.6756604 ]
#  [2.206769   0.5929326 ]
#  [0.59371847 0.56950116]
#  [2.7204733  0.573701  ]
#  [0.66644865 0.6747167 ]
#  [0.6713323  0.5962268 ]
#  [0.6808526  0.60032284]
#  [0.5911913  0.68124825]
#  [0.14396551 3.1411502 ]
#  [0.5987009  0.67266226]]

# %% [markdown]
# # PNN

# %%
conf.last_layer = 'PNN'
model = Linear_base_model()
model.train_model(trainloader, verbose=0)

# %%
plot_means()
# Out:
# mean
# [[ 1.5122279   1.5074518 ]
#  [ 1.5040684  -1.5202388 ]
#  [ 0.00217321 -0.00271575]
#  [-1.5095611  -1.5214896 ]
#  [-1.5091032   1.5110666 ]
#  [-1.5044843   0.00296484]
#  [ 1.5084205  -0.07682994]
#  [ 0.00810253 -1.5068456 ]
#  [ 1.5156482   0.07967237]
#  [ 0.00388998  1.499858  ]]
# stds
# [[0.676537   0.6805116 ]
#  [0.6717963  0.6714483 ]
#  [0.5979816  0.5930467 ]
#  [0.66588265 0.6765011 ]
#  [0.6729234  0.67659014]
#  [0.6722074  0.5938916 ]
#  [0.5669409  0.46454215]
#  [0.59595746 0.6686764 ]
#  [0.5347854  0.44023538]
#  [0.60024536 0.6684157 ]]
