# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from configuration import conf
from utils.data_loader import load_mnist
from models.base import Linear_base_model, Convolutional_base_model
from utils.visualise import *
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import pandas as pd
from playground.env import Environment

# %%
env = Environment()
x,y = env.load_data()

# %%
df = pd.DataFrame(data={'x':x[:,0],'y':x[:,1],'label':y})

# %%
sns.scatterplot(x='x',y='y',hue='label',data=df)

# %%
trainloader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(torch.from_numpy(x).type(torch.FloatTensor),
                                           torch.from_numpy(y.reshape(y.shape[0],1)).type(torch.int64)),
                                          batch_size=10, shuffle=True, num_workers=0)

# %%
def plot_means():
    means = []
    stds = []
    with torch.no_grad():
        for cls in range(2):
            for i in model.last_layer.centers[cls]:
                means.append(i[0].detach().numpy())
                stds.append(i[1].detach().numpy())
    means = np.array(means)
    print('mean')
    print(means)
    print('stds')
    print(np.log(1+np.exp(stds)))
    plt.scatter(means[range(2),0],means[range(2),1], label='class 0')
    plt.scatter(means[range(2,4),0],means[range(2,4),1], label='class 1')
    plt.legend()

# %% [markdown]
# # Dynamic Estimator

# %%
conf.last_layer = 'DY'
model = Linear_base_model()
model.train_model(trainloader, verbose=0)
# Out:
# /opt/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/loss.py:498: UserWarning: Using a target size (torch.Size([10, 1, 2])) that is different to the input size (torch.Size([10, 2])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)

# %%
plt.plot(model.history['loss'])

# %%
plot_means()
# Out:
# mean
# [[-0.60277265  0.6093138 ]
#  [ 0.6116492  -0.63466704]
#  [ 1.9913332   2.426753  ]
#  [ 0.7545268   0.7449717 ]]
# stds
# [[0.61270446 0.6151731 ]
#  [0.60896546 0.61885566]
#  [2.6547594  2.79219   ]
#  [0.932504   0.9197055 ]]

# %% [markdown]
# # Density Estimator

# %%
conf.last_layer = 'DE'
model = Linear_base_model()
model.train_model(trainloader, verbose=0)

# %%
plot_means()
# Out:
# mean
# [[-0.6180856   0.6106715 ]
#  [ 0.6261627  -0.63020766]
#  [ 2.2148151   1.9560894 ]
#  [ 0.76625216  0.7487901 ]]
# stds
# [[0.6069507  0.6148695 ]
#  [0.60339504 0.6138593 ]
#  [2.650807   2.5593803 ]
#  [0.96268183 0.9517233 ]]

# %% [markdown]
# # PNN

# %%
conf.last_layer = 'PNN'
model = Linear_base_model()
model.train_model(trainloader, verbose=0)

# %%
plot_means()
# Out:
# mean
# [[-0.61586905  0.6178378 ]
#  [ 0.53464925  3.6501305 ]
#  [ 1.2389331   1.1849711 ]
#  [ 0.5199458   0.5006537 ]]
# stds
# [[0.63600427 0.6423228 ]
#  [0.45964825 4.6553435 ]
#  [1.9600557  1.9457575 ]
#  [0.26269943 0.265381  ]]
